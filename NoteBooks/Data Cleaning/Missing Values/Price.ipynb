# %%
import pandas as pd
Path = r'C:\Users\zezom\PycharmProjects\CarX\Datasets\Processed\cleaned_dataset.csv'
Cars = pd.read_csv(Path)

# %%
import seaborn as sns
sns.heatmap(Cars.isnull())
# Out:
# <Axes: >

# %%
Cars.isnull().sum()
# Out:
# Name                            0
# Price                         934
# Color                           0
# Mileage                         0
# Make                            0
# Model                           0
# City                            0
# Date Displayed                  0
# Item URL                        0
# Automatic Transmission_Yes      0
# Air Conditioner_Yes             0
# Power Steering_Yes              0
# Remote Control_Yes              0
# Year                            0
# dtype: int64

# %%
Cars['Price'] = Cars['Price'].fillna(Cars['Price'].mean())
Cars.to_csv(r'C:\Users\zezom\PycharmProjects\CarX\Datasets\Processed\cleaned_dataset.csv', index=False)

# %%
import seaborn as sns
sns.heatmap(Cars.isnull())
# Out:
# <Axes: >

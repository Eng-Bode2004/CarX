# %%
import pandas as pd
Path = r'C:\Users\zezom\PycharmProjects\CarX\Datasets\Processed\cleaned_dataset.csv'
Cars = pd.read_csv(Path)

# %%
import seaborn as sns
sns.boxenplot(Cars['Make'])
# Out:
# <Axes: ylabel='Make'>

# %%
import seaborn as sns
sns.boxenplot(Cars['Model'])
# Out:
# <Axes: ylabel='Model'>

# %%
import seaborn as sns
sns.boxenplot(Cars['Color'])
# Out:
# <Axes: ylabel='Color'>

# %%
import seaborn as sns
sns.boxenplot(Cars['Mileage'])
# Out:
# <Axes: ylabel='Mileage'>

# %%
import seaborn as sns
sns.boxenplot(Cars['Price'])
# Out:
# <Axes: ylabel='Price'>

# %%
import seaborn as sns
sns.boxenplot(Cars['Automatic Transmission_Yes'])
# Out:
# <Axes: ylabel='Automatic Transmission_Yes'>

# %%
import seaborn as sns
sns.boxenplot(Cars['Air Conditioner_Yes'])
# Out:
# <Axes: ylabel='Air Conditioner_Yes'>

# %%
import seaborn as sns
sns.boxenplot(Cars['Power Steering_Yes'])
# Out:
# <Axes: ylabel='Power Steering_Yes'>

# %%
import seaborn as sns
sns.boxenplot(Cars['Remote Control_Yes'])
# Out:
# <Axes: ylabel='Remote Control_Yes'>

# %%
import seaborn as sns
sns.boxenplot(Cars['Year'])
# Out:
# <Axes: ylabel='Year'>
